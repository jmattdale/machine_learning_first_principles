# %% [markdown]
# **logit**
# b0 + b1x1 + ... + bnxn
#
# sigmoid = 1 / 1 + e^(-logit)

# %%
import tensorflow as tf
from tensorflow.keras import layers
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([[5], [5], [5], [150], [150], [150]])
y = np.array([[0.0], [0.0], [0.0], [1.0], [1.0], [1.0]])

# %%
dataset = tf.data.Dataset.from_tensor_slices((x, y)).shuffle(4).batch(2)

# %%
inputs_tensor = tf.keras.Input(shape=(1,))
x = layers.Dense(1, activation="sigmoid")(inputs_tensor)
model = tf.keras.Model(inputs=inputs_tensor, outputs=x)

# %%
model.summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_8 (InputLayer)        [(None, 1)]               0
#
#  dense_7 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.05), loss=tf.keras.losses.BinaryCrossentropy(), metrics="accuracy")
model.fit(dataset, epochs=400, verbose=1)
# Out:
# Epoch 1/400
# 3/3 [==============================] - 0s 2ms/step - loss: 3.4533 - accuracy: 0.5000
# Epoch 2/400
# 3/3 [==============================] - 0s 2ms/step - loss: 2.4841 - accuracy: 0.5000
# Epoch 3/400
# 3/3 [==============================] - 0s 2ms/step - loss: 1.5479 - accuracy: 0.5000
# Epoch 4/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8324 - accuracy: 0.5000
# Epoch 5/400
# 3/3 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.6667
# Epoch 6/400
# 3/3 [==============================] - 0s 2ms/step - loss: 4.6715 - accuracy: 0.5000
# Epoch 7/400
# 3/3 [==============================] - 0s 2ms/step - loss: 3.8053 - accuracy: 0.5000
# Epoch 8/400
# 3/3 [==============================] - 0s 2ms/step - loss: 2.8331 - accuracy: 0.5000
# Epoch 9/400
# 3/3 [==============================] - 0s 2ms/step - loss: 1.8754 - accuracy: 0.5000
# Epoch 10/400
# ...

# %%
model.predict(np.array([[5]]))
# Out:
# 1/1 [==============================] - 0s 32ms/step
# array([[0.02655876]], dtype=float32)
